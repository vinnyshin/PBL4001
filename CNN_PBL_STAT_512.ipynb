# %% [markdown]
# # 데이터 셋 만들기

# %%
from IPython.display import display
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

import random

import torchvision.transforms as transforms

import os

from matplotlib.pyplot import imshow

from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

import matplotlib.image as img
from sklearn.model_selection import train_test_split

torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.cuda.manual_seed_all(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(0)
random.seed(0)


if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
class CustomDataset(Dataset):
  def __init__(self, imgs, malices, names):
        super().__init__()
        self.imgs = imgs
        self.malices = malices
        self.names = names
        
  def __len__(self):
      return len(self.imgs)
  
  def __getitem__(self,index):
      return self.imgs[index], self.malices[index], self.names[index]

# %%
from zipfile import ZipFile
from PIL import Image
import zipfile
import cv2
import numpy as np
import random

def convertPILImageToCV2(pil_image):
  np_image = np.array(pil_image)
  open_cv_image = np.array(pil_image) 

  open_cv_image = open_cv_image[:, :, ::-1].copy() 

  return open_cv_image

benign_path = '/content/drive/MyDrive/Malware Analysis/kisa_dataset/benign_image_512.zip'
malign_path = '/content/drive/MyDrive/Malware Analysis/kisa_dataset/malign_image_512.zip'
benign_zip = ZipFile(benign_path,'r')
malign_zip = ZipFile(malign_path,'r')

#benign
benign_info_list = benign_zip.infolist()
benign_name_list = benign_zip.namelist()
malign_info_list = malign_zip.infolist()
malign_name_list = malign_zip.namelist()

benign_set = []
malign_set = []



for i in range(len(benign_info_list)):
  _file = benign_zip.open(benign_info_list[i])
  img = Image.open(_file)
  img = convertPILImageToCV2(img)
  name = benign_name_list[i]
  benign_set.append((img, 0, name))
  

for i in range(len(malign_info_list)):
  _file = malign_zip.open(malign_info_list[i])
  img = Image.open(_file)
  img = convertPILImageToCV2(img)
  name = malign_name_list[i]
  malign_set.append((img, 1, name))
  

#데이터 셔플링
random.shuffle(benign_set)
random.shuffle(malign_set)
# 셔플된 데이터에서 테스트셋, 트레인셋 구성.

num_each_test = 400

raw_test_set = benign_set[:num_each_test] + malign_set[:num_each_test]
random.shuffle(raw_test_set)
raw_train_set = benign_set[num_each_test:] + malign_set[num_each_test:]
random.shuffle(raw_train_set)

# %%
# benign_zip.namelist()

# %% [markdown]
# ## Normalizing

# %%
train_meanRGB = [np.mean(x, axis=(1,2)) for x,_, __ in raw_train_set]
train_stdRGB = [np.std(x, axis=(1,2)) for x,_, __ in raw_train_set]

train_meanR = np.mean([m[0] for m in train_meanRGB])
train_meanG = np.mean([m[1] for m in train_meanRGB])
train_meanB = np.mean([m[2] for m in train_meanRGB])

train_stdR = np.mean([s[0] for s in train_stdRGB])
train_stdG = np.mean([s[1] for s in train_stdRGB])
train_stdB = np.mean([s[2] for s in train_stdRGB])

test_meanRGB = [np.mean(x, axis=(1,2)) for x,_, __ in raw_test_set]
test_stdRGB = [np.std(x, axis=(1,2)) for x,_, __ in raw_test_set]

test_meanR = np.mean([m[0] for m in test_meanRGB])
test_meanG = np.mean([m[1] for m in test_meanRGB])
test_meanB = np.mean([m[2] for m in test_meanRGB])

test_stdR = np.mean([s[0] for s in test_stdRGB])
test_stdG = np.mean([s[1] for s in test_stdRGB])
test_stdB = np.mean([s[2] for s in test_stdRGB])



normalized_zero_r = (0-test_meanR)/test_stdR
print(normalized_zero_r)
# Out:
# -0.04826441019184021

# %%
train_transform = transforms.Compose([transforms.ToPILImage(),
                                      transforms.ToTensor(),
                                      transforms.Normalize([train_meanR,train_meanG,train_meanB],[train_stdR, train_stdG, train_stdB])
                                      ])
test_transform = transforms.Compose([transforms.ToPILImage(),
                                      transforms.ToTensor(),
                                     transforms.Normalize([test_meanR, test_meanG, test_meanB],[test_stdR, test_stdG, test_stdB])
                                      ])

train_imgs, train_malices, train_names = [],[], []
test_imgs, test_malices, test_names = [],[],[]


for img,mal,name in raw_train_set:
  train_imgs.append(train_transform(img))
  train_malices.append(mal)
  train_names.append(name)
for img,mal,name in raw_test_set:
  test_imgs.append(test_transform(img))
  test_malices.append(mal)
  test_names.append(name)


train_set = CustomDataset(train_imgs, train_malices, train_names)
test_set = CustomDataset(test_imgs, test_malices, test_names)

# %% [markdown]
# # 모델 정의

# %%
# %%time
class CNN(nn.Module): 
    def __init__(self):
      super(CNN, self).__init__()
      
      self.layer1 = nn.Sequential(
          # kerner size : 필터 크기
          nn.Conv2d(in_channels=3, out_channels=29, kernel_size=5),
          nn.BatchNorm2d(29),
          nn.ReLU(inplace=True),
          nn.MaxPool2d(2),
          nn.Dropout(0.2)
      ) # output size : (이미지 width - 커널사이즈 + 2*패딩사이즈)/stride + 1 -> 
      # (512 - 5) + 1 -> 508 -> 254
      # (256 - 5 + 2* 0)/1 + 1 252 -> 126 126(풀링)
      # (128 - 5) + 1 -> 124 -> 62 (풀링)
      # (64 - 5 + 2* 0)/1 + 1 -> 60 -> 30 (풀링)
      # 
      self.layer2 = nn.Sequential(
          nn.Conv2d(in_channels=29, out_channels=39, kernel_size=5),
          nn.BatchNorm2d(39),
          nn.ReLU(inplace=True),
          nn.MaxPool2d(2),
          nn.Dropout(0.2)
      )
      # 

      # 256 인경우 input : 126 * 126, 128인 경우 30*30
      # (254 - 5) + 1 : 250 -> 125
      # (126-5)/1+1 : 122 -> 61
      # (62 - 5) + 1 : 58 -> 풀링하면 29
      # (30-5) +1 -> 26, 풀링하면 13
      # 126 * 126 * 10 --CONV2--> 122 * 122 * 20 --MAX POOL--> 61 * 61 * 20

      ## 60 60 
      
      # 256 256 일때 39 * 61 * 61, out_features = 183
      self.layer3 = nn.Sequential(
          nn.Linear(in_features=39 * 125 * 125, out_features=183, bias=True),
          nn.ReLU(inplace=True)
      )

      # self.layer4 = nn.Sequential(
      #     nn.Linear(in_features=183, out_features=2, bias=True),
      # )
      self.layer4 = nn.Sequential(
          nn.Linear(in_features=183, out_features=2, bias=True),
      )

    def forward(self, x):
      x = self.layer1(x)
      x = self.layer2(x)
      x = x.view(-1, 39 * 125 * 125)
      x = self.layer3(x)
      x = self.layer4(x)
      return x
# Out:
# CPU times: user 31 µs, sys: 0 ns, total: 31 µs
# Wall time: 34.1 µs

# %%
train_losses = []
valid_losses = []

num_epochs = 100
batch_size = 16
learning_rate = 0.0005387
weight_decay = 0.01594
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = CNN().to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(),lr = learning_rate, weight_decay=weight_decay)

print(device)
print(model)

train_loader = DataLoader(dataset = train_set, batch_size = batch_size, shuffle=True, num_workers=0)
test_loader = DataLoader(dataset = test_set, batch_size = batch_size, shuffle=False, num_workers=0)
# Out:
# cuda
# CNN(
#   (layer1): Sequential(
#     (0): Conv2d(3, 29, kernel_size=(5, 5), stride=(1, 1))
#     (1): BatchNorm2d(29, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.2, inplace=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(29, 39, kernel_size=(5, 5), stride=(1, 1))
#     (1): BatchNorm2d(39, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.2, inplace=False)
#   )
#   (layer3): Sequential(
#     (0): Linear(in_features=609375, out_features=183, bias=True)
#     (1): ReLU(inplace=True)
#   )
#   (layer4): Sequential(
#     (0): Linear(in_features=183, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# # Training

# %%
# torch.cuda.empty_cache()

# %%
# keeping-track-of-losses 
# %%time 
import time

  # 현재시각 - 시작시간 = 실행 시간
for epoch in range(1, num_epochs + 1):
    # keep-track-of-training-and-validation-loss
    train_loss = 0.0
    valid_loss = 0.0
    
    # training-the-model
    model.train()
    
    start = time.time()
    for data, target,_ in train_loader:
        
        # move-tensors-to-GPU 
        data = data.to(device)
        target = target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * data.size(0)
        
    # validate-the-model
    model.eval()
    correct = 0
    total = 0
        
    for data, target,_ in test_loader:
        
        data = data.to(device)
        target = target.to(device)
        output = model(data)
        
        _, predicted = torch.max(output.data, 1)
        total += target.size(0)
        correct += (predicted == target).sum().item()
              
        loss = criterion(output, target)
        # update-average-validation-loss 
        valid_loss += loss.item() * data.size(0)
    
    train_loss = train_loss/len(train_loader.sampler)
    valid_loss = valid_loss/len(test_loader.sampler)
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)
    # print-training/validation-statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))
    print("time :", time.time() - start)
    print('Test Accuracy of the model: {} %'.format(100 * correct / total))

    # # test-the-model
    # with torch.no_grad():
    #     correct = 0
    #     total = 0
    #     for images, labels,_ in test_loader:
    #         images = images.to(device)
    #         labels = labels.to(device)
    #         outputs = model(images)
    #         _, predicted = torch.max(outputs.data, 1)
    #         total += labels.size(0)
    #         correct += (predicted == labels).sum().item()
              
    #     print('Test Accuracy of the model: {} %'.format(100 * correct / total))
# Out:
# Epoch: 1 	Training Loss: 3.835003 	Validation Loss: 0.969528
# time : 20.531389713287354
# Test Accuracy of the model: 78.375 %
# Epoch: 2 	Training Loss: 0.808143 	Validation Loss: 0.800374
# time : 20.2689106464386
# Test Accuracy of the model: 80.0 %
# Epoch: 3 	Training Loss: 0.386963 	Validation Loss: 0.595271
# time : 20.258495330810547
# Test Accuracy of the model: 81.0 %
# Epoch: 4 	Training Loss: 0.297360 	Validation Loss: 0.414728
# time : 20.279089212417603
# Test Accuracy of the model: 86.5 %
# Epoch: 5 	Training Loss: 0.284732 	Validation Loss: 0.541991
# time : 20.259080410003662
# Test Accuracy of the model: 83.25 %
# Epoch: 6 	Training Loss: 0.296683 	Validation Loss: 0.407744
# time : 20.262227058410645
# Test Accuracy of the model: 87.375 %
# Epoch: 7 	Training Loss: 0.227373 	Validation Loss: 0.558211
# time : 20.262563705444336
# Test Accuracy of the model: 78.75 %
# Epoch: 8 	Training Loss: 0.207244 	Validation Loss: 0.428082
# time : 20.27385449409485
# Test Accuracy of the model: 87.375 %
# Epoch: 9 	Training Loss: 0.199264 	Validation Loss: 0.365159
# time : 20.24497938156128
# Test Accuracy of the model: 88.0 %
# Epoch: 10 	Training Loss: 0.189888 	Validation Loss: 0.373476
# time : 20.254201650619507
# Test Accuracy of the model: 86.875 %
# Epoch: 11 	Training Loss: 0.211891 	Validation Loss: 0.395281
# time : 20.243382930755615
# Test Accuracy of the model: 86.375 %
# Epoch: 12 	Training Loss: 0.210462 	Validation Loss: 0.515021
# time : 20.240065813064575
# Test Accuracy of the model: 84.5 %
# Epoch: 13 	Training Loss: 0.172884 	Validation Loss: 0.333512
# time : 20.233421802520752
# Test Accuracy of the model: 88.375 %
# Epoch: 14 	Training Loss: 0.174895 	Validation Loss: 0.516877
# time : 20.20980167388916
# Test Accuracy of the model: 85.0 %
# Epoch: 15 	Training Loss: 0.151877 	Validation Loss: 0.587658
# time : 20.291038036346436
# Test Accuracy of the model: 81.0 %
# Epoch: 16 	Training Loss: 0.193839 	Validation Loss: 0.341747
# time : 20.28356122970581
# Test Accuracy of the model: 87.5 %
# Epoch: 17 	Training Loss: 0.169102 	Validation Loss: 0.490546
# time : 20.27836847305298
# Test Accuracy of the model: 81.25 %
# Epoch: 18 	Training Loss: 0.144589 	Validation Loss: 0.338882
# time : 20.267617225646973
# Test Accuracy of the model: 86.625 %
# Epoch: 19 	Training Loss: 0.145109 	Validation Loss: 0.388366
# time : 20.25037693977356
# Test Accuracy of the model: 84.5 %
# Epoch: 20 	Training Loss: 0.142065 	Validation Loss: 0.404034
# time : 20.273908376693726
# Test Accuracy of the model: 86.375 %
# Epoch: 21 	Training Loss: 0.131623 	Validation Loss: 0.464200
# time : 20.26974606513977
# Test Accuracy of the model: 86.75 %
# Epoch: 22 	Training Loss: 0.143842 	Validation Loss: 0.299590
# time : 20.259214878082275
# Test Accuracy of the model: 88.25 %
# Epoch: 23 	Training Loss: 0.129935 	Validation Loss: 0.322425
# time : 20.241204738616943
# Test Accuracy of the model: 87.75 %
# Epoch: 24 	Training Loss: 0.114499 	Validation Loss: 0.335546
# time : 20.223501443862915
# Test Accuracy of the model: 89.0 %
# Epoch: 25 	Training Loss: 0.110097 	Validation Loss: 0.322402
# time : 20.231813430786133
# Test Accuracy of the model: 88.375 %
# Epoch: 26 	Training Loss: 0.122645 	Validation Loss: 0.379443
# time : 20.235701322555542
# Test Accuracy of the model: 87.375 %
# Epoch: 27 	Training Loss: 0.117837 	Validation Loss: 0.313177
# time : 20.235246419906616
# Test Accuracy of the model: 88.625 %
# Epoch: 28 	Training Loss: 0.114314 	Validation Loss: 0.451761
# time : 20.241727590560913
# Test Accuracy of the model: 78.875 %
# Epoch: 29 	Training Loss: 0.105453 	Validation Loss: 0.336044
# time : 20.252201318740845
# Test Accuracy of the model: 86.875 %
# Epoch: 30 	Training Loss: 0.094365 	Validation Loss: 0.330356
# time : 20.25145983695984
# Test Accuracy of the model: 87.875 %
# Epoch: 31 	Training Loss: 0.093429 	Validation Loss: 0.390168
# time : 20.24411964416504
# Test Accuracy of the model: 86.75 %
# Epoch: 32 	Training Loss: 0.113154 	Validation Loss: 0.361693
# time : 20.218528509140015
# Test Accuracy of the model: 88.0 %
# Epoch: 33 	Training Loss: 0.093580 	Validation Loss: 0.370592
# time : 20.246904611587524
# Test Accuracy of the model: 87.125 %
# Epoch: 34 	Training Loss: 0.095812 	Validation Loss: 0.312250
# time : 20.238863229751587
# Test Accuracy of the model: 88.5 %
# Epoch: 35 	Training Loss: 0.103104 	Validation Loss: 0.313987
# time : 20.226820468902588
# Test Accuracy of the model: 88.625 %
# Epoch: 36 	Training Loss: 0.089387 	Validation Loss: 0.296433
# time : 20.23922824859619
# Test Accuracy of the model: 88.625 %
# Epoch: 37 	Training Loss: 0.095854 	Validation Loss: 0.381424
# time : 20.245840311050415
# Test Accuracy of the model: 88.0 %
# Epoch: 38 	Training Loss: 0.089893 	Validation Loss: 0.403068
# time : 20.248027324676514
# Test Accuracy of the model: 85.75 %
# Epoch: 39 	Training Loss: 0.094091 	Validation Loss: 0.398710
# time : 20.231223821640015
# Test Accuracy of the model: 86.125 %
# Epoch: 40 	Training Loss: 0.096432 	Validation Loss: 0.387799
# time : 20.247454404830933
# Test Accuracy of the model: 84.25 %
# Epoch: 41 	Training Loss: 0.088006 	Validation Loss: 0.402064
# time : 20.246735095977783
# Test Accuracy of the model: 86.375 %
# Epoch: 42 	Training Loss: 0.084278 	Validation Loss: 0.364038
# time : 20.227357149124146
# Test Accuracy of the model: 89.5 %
# Epoch: 43 	Training Loss: 0.083270 	Validation Loss: 0.404543
# time : 20.217195749282837
# Test Accuracy of the model: 87.625 %
# Epoch: 44 	Training Loss: 0.087611 	Validation Loss: 0.362172
# time : 20.26167917251587
# Test Accuracy of the model: 87.75 %
# Epoch: 45 	Training Loss: 0.097713 	Validation Loss: 0.323235
# time : 20.271632194519043
# Test Accuracy of the model: 87.75 %
# Epoch: 46 	Training Loss: 0.086855 	Validation Loss: 0.341574
# time : 20.24760627746582
# Test Accuracy of the model: 87.5 %
# Epoch: 47 	Training Loss: 0.084244 	Validation Loss: 0.338604
# time : 20.273379802703857
# Test Accuracy of the model: 87.0 %
# Epoch: 48 	Training Loss: 0.068908 	Validation Loss: 0.363630
# time : 20.248367309570312
# Test Accuracy of the model: 89.375 %
# Epoch: 49 	Training Loss: 0.082140 	Validation Loss: 0.496066
# time : 20.233561992645264
# Test Accuracy of the model: 83.625 %
# Epoch: 50 	Training Loss: 0.090259 	Validation Loss: 0.387720
# time : 20.235886573791504
# Test Accuracy of the model: 88.5 %
# Epoch: 51 	Training Loss: 0.091811 	Validation Loss: 0.359263
# time : 20.237306594848633
# Test Accuracy of the model: 87.375 %
# Epoch: 52 	Training Loss: 0.085637 	Validation Loss: 0.354699
# time : 20.244948625564575
# Test Accuracy of the model: 86.75 %
# Epoch: 53 	Training Loss: 0.074616 	Validation Loss: 0.433229
# time : 20.24233603477478
# Test Accuracy of the model: 86.75 %
# Epoch: 54 	Training Loss: 0.067900 	Validation Loss: 0.427327
# time : 20.24237632751465
# Test Accuracy of the model: 86.375 %
# Epoch: 55 	Training Loss: 0.084799 	Validation Loss: 0.384269
# time : 20.195735931396484
# Test Accuracy of the model: 86.375 %
# Epoch: 56 	Training Loss: 0.083334 	Validation Loss: 0.471818
# time : 20.182133436203003
# Test Accuracy of the model: 85.25 %
# Epoch: 57 	Training Loss: 0.090629 	Validation Loss: 0.370826
# time : 20.240896463394165
# Test Accuracy of the model: 87.625 %
# Epoch: 58 	Training Loss: 0.080940 	Validation Loss: 0.407885
# time : 20.251649141311646
# Test Accuracy of the model: 87.75 %
# Epoch: 59 	Training Loss: 0.086683 	Validation Loss: 0.418391
# time : 20.18195652961731
# Test Accuracy of the model: 85.875 %
# Epoch: 60 	Training Loss: 0.079770 	Validation Loss: 0.362776
# time : 20.197696685791016
# Test Accuracy of the model: 86.0 %
# Epoch: 61 	Training Loss: 0.078429 	Validation Loss: 0.374512
# time : 20.187464237213135
# Test Accuracy of the model: 87.75 %
# Epoch: 62 	Training Loss: 0.077543 	Validation Loss: 0.368734
# time : 20.18920922279358
# Test Accuracy of the model: 86.875 %
# Epoch: 63 	Training Loss: 0.073601 	Validation Loss: 0.372122
# time : 20.193068981170654
# Test Accuracy of the model: 86.875 %
# Epoch: 64 	Training Loss: 0.077740 	Validation Loss: 0.404567
# time : 20.20113515853882
# Test Accuracy of the model: 88.25 %
# Epoch: 65 	Training Loss: 0.082784 	Validation Loss: 0.412901
# time : 20.196014642715454
# Test Accuracy of the model: 84.375 %
# Epoch: 66 	Training Loss: 0.080705 	Validation Loss: 0.366645
# time : 20.190075635910034
# Test Accuracy of the model: 87.625 %
# Epoch: 67 	Training Loss: 0.072476 	Validation Loss: 0.348595
# time : 20.19297504425049
# Test Accuracy of the model: 88.75 %
# Epoch: 68 	Training Loss: 0.082924 	Validation Loss: 0.406657
# time : 20.176955223083496
# Test Accuracy of the model: 87.125 %
# Epoch: 69 	Training Loss: 0.065986 	Validation Loss: 0.448753
# time : 20.18905520439148
# Test Accuracy of the model: 86.125 %
# Epoch: 70 	Training Loss: 0.083154 	Validation Loss: 0.427624
# time : 20.191948175430298
# Test Accuracy of the model: 87.0 %
# Epoch: 71 	Training Loss: 0.090291 	Validation Loss: 0.375745
# time : 20.180835723876953
# Test Accuracy of the model: 87.875 %
# Epoch: 72 	Training Loss: 0.081999 	Validation Loss: 0.416282
# time : 20.186680555343628
# Test Accuracy of the model: 87.375 %
# Epoch: 73 	Training Loss: 0.075592 	Validation Loss: 0.416205
# time : 20.192065715789795
# Test Accuracy of the model: 85.375 %
# Epoch: 74 	Training Loss: 0.077155 	Validation Loss: 0.458899
# time : 20.17813491821289
# Test Accuracy of the model: 84.125 %
# Epoch: 75 	Training Loss: 0.075633 	Validation Loss: 0.383255
# time : 20.181307792663574
# Test Accuracy of the model: 87.5 %
# Epoch: 76 	Training Loss: 0.080599 	Validation Loss: 0.385349
# time : 20.18756675720215
# Test Accuracy of the model: 87.0 %
# Epoch: 77 	Training Loss: 0.084830 	Validation Loss: 0.373766
# time : 20.202592134475708
# Test Accuracy of the model: 85.375 %
# Epoch: 78 	Training Loss: 0.074432 	Validation Loss: 0.407111
# time : 20.18633270263672
# Test Accuracy of the model: 87.125 %
# Epoch: 79 	Training Loss: 0.070117 	Validation Loss: 0.314313
# time : 20.18147897720337
# Test Accuracy of the model: 89.375 %
# Epoch: 80 	Training Loss: 0.074519 	Validation Loss: 0.354484
# time : 20.251317977905273
# Test Accuracy of the model: 87.0 %
# Epoch: 81 	Training Loss: 0.074215 	Validation Loss: 0.368737
# time : 20.21177840232849
# Test Accuracy of the model: 87.5 %
# Epoch: 82 	Training Loss: 0.074179 	Validation Loss: 0.462435
# time : 20.222787380218506
# Test Accuracy of the model: 85.375 %
# Epoch: 83 	Training Loss: 0.077696 	Validation Loss: 0.388174
# time : 20.20579981803894
# Test Accuracy of the model: 86.25 %
# Epoch: 84 	Training Loss: 0.079412 	Validation Loss: 0.331433
# time : 20.187044143676758
# Test Accuracy of the model: 87.625 %
# Epoch: 85 	Training Loss: 0.090702 	Validation Loss: 0.368962
# time : 20.176178455352783
# Test Accuracy of the model: 86.0 %
# Epoch: 86 	Training Loss: 0.075311 	Validation Loss: 0.376929
# time : 20.199398517608643
# Test Accuracy of the model: 87.75 %
# Epoch: 87 	Training Loss: 0.072338 	Validation Loss: 0.397927
# time : 20.224735260009766
# Test Accuracy of the model: 87.125 %
# Epoch: 88 	Training Loss: 0.065728 	Validation Loss: 0.410151
# time : 20.206661701202393
# Test Accuracy of the model: 87.375 %
# Epoch: 89 	Training Loss: 0.076025 	Validation Loss: 0.334540
# time : 20.18653678894043
# Test Accuracy of the model: 89.0 %
# Epoch: 90 	Training Loss: 0.070812 	Validation Loss: 0.393963
# time : 20.186298847198486
# Test Accuracy of the model: 86.625 %
# Epoch: 91 	Training Loss: 0.083884 	Validation Loss: 0.435477
# time : 20.166587352752686
# Test Accuracy of the model: 85.625 %
# Epoch: 92 	Training Loss: 0.069962 	Validation Loss: 0.411879
# time : 20.157125234603882
# Test Accuracy of the model: 87.5 %
# Epoch: 93 	Training Loss: 0.081360 	Validation Loss: 0.387696
# time : 20.166630268096924
# Test Accuracy of the model: 88.125 %
# Epoch: 94 	Training Loss: 0.068909 	Validation Loss: 0.438693
# time : 20.20396876335144
# Test Accuracy of the model: 87.5 %
# Epoch: 95 	Training Loss: 0.074790 	Validation Loss: 0.492940
# time : 20.298543453216553
# Test Accuracy of the model: 86.125 %
# Epoch: 96 	Training Loss: 0.070633 	Validation Loss: 0.407081
# time : 20.260303497314453
# Test Accuracy of the model: 86.25 %
# Epoch: 97 	Training Loss: 0.069363 	Validation Loss: 0.379024
# time : 20.22261118888855
# Test Accuracy of the model: 87.625 %
# Epoch: 98 	Training Loss: 0.066394 	Validation Loss: 0.424888
# time : 20.192838430404663
# Test Accuracy of the model: 85.75 %
# Epoch: 99 	Training Loss: 0.086127 	Validation Loss: 0.472673
# time : 20.186928749084473
# Test Accuracy of the model: 84.75 %
# Epoch: 100 	Training Loss: 0.080112 	Validation Loss: 0.453158
# time : 20.216837406158447
# Test Accuracy of the model: 86.25 %

# %% [markdown]
# # Testing

# %%
# test-the-model
model.eval()  # it-disables-dropout
predict = []
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels,_ in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        predict.extend(predicted.detach().cpu())
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
          
    print('Test Accuracy of the model: {} %'.format(100 * correct / total))

# Save 
torch.save(model.state_dict(), 'model.ckpt')
# Out:
# Test Accuracy of the model: 86.25 %

# %%
#predict
test_loader

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.plot(train_losses, label='Training loss')
plt.plot(valid_losses, label='test loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(frameon=False)

# %%
from sklearn.metrics import confusion_matrix, f1_score
t = confusion_matrix(test_set.malices, predict)
f1 = f1_score(test_set.malices, predict)
print(t)

np_predict = np.array(predict)
np_malices = np.array(test_set.malices)


t = np_predict == np_malices # T : 정답이 맞는 경우 
f = np_predict != np_malices # F : 정답에 틀린 경우

# 각 그룹의 베이직 블록 개수, 픽셀 개수, (베이직 블록 - 픽셀 개수), 그룹당 평균, 중간
index_true = np.where(t)[0]
index_false = np.where(f)[0]
benign_block_dir = '/content/drive/MyDrive/Malware Analysis/kisa_dataset/benign_block/'
malign_block_dir = '/content/drive/MyDrive/Malware Analysis/kisa_dataset/malign_block/'
# Out:
# [[312  88]
#  [ 22 378]]

# %%
print(f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dc6311560b14> in <module>()
# ----> 1 print(f1)
#
# NameError: name 'f1' is not defined

# %%
import torch
import math


E = 0.0000001

def truncate(num, n):
    integer = int(num * (10**n))/(10**n)
    return float(integer)

def get_num_pixel(tensor_r, normalized_zero_r):
  pixels = (tensor_r.numpy() - normalized_zero_r) > E 
  cnt = np.count_nonzero(pixels)
  return cnt

true_benign_basic_block_nums = []
true_malign_basic_block_nums = []
true_benign_pixel_nums = []
true_malign_pixel_nums = []

false_benign_basic_block_nums = []
false_malign_basic_block_nums = []
false_benign_pixel_nums = []
false_malign_pixel_nums = []

normalized_zero_r = (0-test_meanR)/test_stdR
normalized_zero_r = truncate(normalized_zero_r,8)

demo = 400 # 최대 400까지 

for idx in index_true[:demo]:
  tensor, malice, name = test_set[idx]
  name = name.replace('.png','.txt')
  path = benign_block_dir+name if malice == 0 else malign_block_dir+name
  # 베이직 블록 개수 세기 위해, 파일을 엽니다. 
  block_file = open(path,'r')
  num_block = len(block_file.readlines())
  num_pixels = get_num_pixel(tensor[0], normalized_zero_r)
  
  # 베이직 블록 개수, 픽셀 개수를 입력합니다. 
  if malice == 0:
    true_benign_basic_block_nums.append(num_block)
    true_benign_pixel_nums.append(num_pixels)
    
  else: 
    true_malign_basic_block_nums.append(num_block)
    true_malign_pixel_nums.append(num_pixels)

print()
for idx in index_false[:demo]:
  tensor, malice, name = test_set[idx]
  name = name.replace('.png','.txt')
  path = benign_block_dir+name if malice == 0 else malign_block_dir+name
  # 베이직 블록 개수 세기 위해, 파일을 엽니다. 
  block_file = open(path,'r')
  num_block = len(block_file.readlines())
  num_pixels = get_num_pixel(tensor[0], normalized_zero_r)
  
  # 베이직 블록 개수, 픽셀 개수를 입력합니다. 
  if malice == 0:
    false_benign_basic_block_nums.append(num_block)
    false_benign_pixel_nums.append(num_pixels)
  else: 
    false_malign_basic_block_nums.append(num_block)
    false_malign_pixel_nums.append(num_pixels)

# %%
# True_benign
# True_malign
# False_benign
# False_malign
def stat(block_nums, pixel_nums, label):
  min_block = min(block_nums)
  mean_block = np.mean(block_nums)
  min_pixels = min(pixel_nums)
  mean_pixels = np.mean(pixel_nums)
  diff = np.array(block_nums) - np.array(pixel_nums)
  min_diff = min(diff)
  mean_diff = np.mean(diff)

  median_block = np.median(block_nums)
  median_pixels = np.median(pixel_nums)
  
  print(f'====={label}=====')
  print(f'블록 개수 평균 : {mean_block}, 픽셀 개수 평균 : {mean_pixels}, 평균 차이 : {mean_diff} 소실률: {(mean_pixels/mean_block) * 100}%')
  print(f'중간값 블록 : {median_block}, 중간값 픽셀 : {median_pixels}')

stat(true_benign_basic_block_nums, true_benign_pixel_nums, "True benign")
stat(true_malign_basic_block_nums, true_malign_pixel_nums, 'True malign')
stat(false_benign_basic_block_nums, false_benign_pixel_nums, 'False benign')
stat(false_malign_basic_block_nums, false_malign_pixel_nums, 'False malign')
# Out:
# =====True benign=====
# 블록 개수 평균 : 1557.621301775148, 픽셀 개수 평균 : 763.0118343195267, 평균 차이 : 794.6094674556213 소실률: 48.98570875025642%
# 중간값 블록 : 691.0, 중간값 픽셀 : 527.0
# =====True malign=====
# 블록 개수 평균 : 1788.6883116883116, 픽셀 개수 평균 : 660.077922077922, 평균 차이 : 1128.6103896103896 소실률: 36.902903527942556%
# 중간값 블록 : 361.0, 중간값 픽셀 : 241.0
# =====False benign=====
# 블록 개수 평균 : 1457.8522727272727, 픽셀 개수 평균 : 676.5681818181819, 평균 차이 : 781.2840909090909 소실률: 46.40855554949295%
# 중간값 블록 : 602.0, 중간값 픽셀 : 399.5
# =====False malign=====
# 블록 개수 평균 : 1197.4545454545455, 픽셀 개수 평균 : 554.9545454545455, 평균 차이 : 642.5 소실률: 46.34451867597935%
# 중간값 블록 : 357.5, 중간값 픽셀 : 218.0

# %%
# 잘 구분되는 benign, malign

# %%
import torch
import torchvision
import torchvision.transforms as T
from PIL import Image

import matplotlib.pyplot as plt
import torchvision.transforms as transforms


indecies = np.where(t)[0]

cnt = 0

for i in indecies:
  # wandb.log({"fakge": [wandb.Image(i.reshape([256, 256, 3]), mode="RGB") for i in test_set[i][0]]})
  tf = T.ToPILImage()
  img_t = tf(raw_test_set[i][0])
  plt.imshow(img_t)
  plt.show()
  print('ang')
  
  cnt += 1
  if cnt > 20 :
    break
# Out:
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang

# %%
indecies = np.where(f)[0]

cnt = 0

for i in indecies:
  # wandb.log({"fakge": [wandb.Image(i.reshape([256, 256, 3]), mode="RGB") for i in test_set[i][0]]})
  tf = T.ToPILImage()
  img_t = tf(raw_test_set[i][0])
  plt.imshow(img_t)
  plt.show()
  print('ang')
  
  cnt += 1
  if cnt > 20 :
    break
# Out:
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
# ang
